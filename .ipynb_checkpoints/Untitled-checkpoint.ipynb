# %%
import olympics
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
plt.style.use('seaborn')

# %%
country = olympics.Country("Spain")

# %%
country.historical_olympics_data()
# Out:
#        index     ID                              Name Sex   Age  Height  \
# 0     151032  75797          Luis Jess Martnez Encabo   M  32.0   172.0
# 1     151031  75797          Luis Jess Martnez Encabo   M  32.0   172.0
# 2     151007  75781                Laura Martnez Ruiz   F  16.0   149.0
# 3      68258  34867              Nieves Fernndez Mata   F  23.0     NaN
# 4      41946  21618           Mihaela Ciobanu Ciobanu   F  39.0   175.0
# ...      ...    ...                               ...  ..   ...     ...
# 4890  198669  99766  Antonio Manuel Reina Ballesteros   M  31.0   186.0
# 4891   65082  33306                 Reyes Estvez Lpez   M  28.0   187.0
# 4892   82952  42137         Jos Ramn Goyeneche Bilbao   M  23.0   174.0
# 4893   52527  26983              Gervasio Deferr ngel   M  19.0   166.0
# 4894   65081  33306                 Reyes Estvez Lpez   M  19.0   187.0
#
#       Weight   Team  NOC        Games  Year  Season       City       Sport  \
# ...

# %%
year_a = 2016
year_b = 1992

# %%
height = country.get_histogram(metric_val="Height",_range=range(150,200),year_a=year_a,year_b=year_b)

# %%
height[0]
# Out:
# (150, 151]     4
# (151, 152]     0
# (152, 153]     0
# (153, 154]     0
# (154, 155]     0
# (155, 156]     1
# (156, 157]     1
# (157, 158]     0
# (158, 159]     1
# (159, 160]     8
# (160, 161]     2
# (161, 162]     8
# (162, 163]    12
# (163, 164]     6
# (164, 165]    10
# (165, 166]     5
# (166, 167]    13
# (167, 168]    11
# (168, 169]     9
# (169, 170]    24
# (170, 171]     9
# (171, 172]    17
# (172, 173]    19
# (173, 174]     9
# (174, 175]    13
# (175, 176]     9
# (176, 177]     8
# (177, 178]    14
# (178, 179]     3
# (179, 180]    25
# (180, 181]    10
# (181, 182]    14
# (182, 183]    10
# (183, 184]     7
# (184, 185]    11
# (185, 186]     4
# (186, 187]     8
# (187, 188]    11
# (188, 189]     4
# (189, 190]     6
# (190, 191]     4
# (191, 192]     6
# (192, 193]     6
# (193, 194]     3
# (194, 195]     4
# (195, 196]     3
# (196, 197]     0
# (197, 198]     3
# (198, 199]     0
# Name: 2016, dtype: int64
